# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
sns.set()

# %%
df = pd.read_csv("./datasets/2008_swing_states.csv")

# %%
df.head()
# Out:
#   state           county  total_votes  dem_votes  rep_votes  dem_share
# 0    PA      Erie County       127691      75775      50351      60.08
# 1    PA  Bradford County        25787      10306      15057      40.64
# 2    PA     Tioga County        17984       6390      11326      36.07
# 3    PA    McKean County        15947       6465       9224      41.21
# 4    PA    Potter County         7507       2300       5109      31.04

# %%
bin_edges = [0,50,100]
df.hist(column='dem_share',bins=bin_edges) #15)
plt.xlabel('% of Democrat Share of Votes')
plt.ylabel('Count of Counties')
plt.show()

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
df_iris= pd.DataFrame(iris['data'],columns=iris['feature_names'])
df_iris['species']=iris['target']
df_iris['species_names']=iris['target']
df_iris.species_names.replace(dict(enumerate(iris.target_names)),inplace=True)

# %%
df_iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species species_names
# 0        0        setosa
# 1        0        setosa
# 2        0        setosa
# 3        0        setosa
# 4        0        setosa

# %%
df_iris.describe(include='all')
# Out:
#         sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count          150.000000        150.000000         150.000000
# unique                NaN               NaN                NaN
# top                   NaN               NaN                NaN
# freq                  NaN               NaN                NaN
# mean             5.843333          3.054000           3.758667
# std              0.828066          0.433594           1.764420
# min              4.300000          2.000000           1.000000
# 25%              5.100000          2.800000           1.600000
# 50%              5.800000          3.000000           4.350000
# 75%              6.400000          3.300000           5.100000
# max              7.900000          4.400000           6.900000
#
#         petal width (cm)     species species_names
# count         150.000000  150.000000           150
# unique               NaN         NaN             3
# top                  NaN         NaN     virginica
# freq                 NaN         NaN            50
# mean            1.198667    1.000000           NaN
# std             0.763161    0.819232           NaN
# min             0.100000    0.000000           NaN
# 25%             0.300000    0.000000           NaN
# 50%             1.300000    1.000000           NaN
# 75%             1.800000    2.000000           NaN
# max             2.500000    2.000000           NaN

# %%
df_iris.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# species                int32
# species_names         object
# dtype: object

# %%
df_iris.shape[0]
# Out:
# 150

# %%
n_bins=int(np.sqrt(df_iris[df_iris['species_names']=='versicolor'].shape[0]))
df_iris[df_iris['species_names']=='versicolor'].hist(column='petal length (cm)',bins=n_bins)
plt.xlabel('Petal Length (cm)')
plt.ylabel('Count of Flowers')
plt.show()

# %%
df_iris.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# species                int32
# species_names         object
# dtype: object

# %%
sns.swarmplot(x='species_names',y='petal length (cm)',data=df_iris)
plt.show()

# %%
#define ECDFs
def ecdf(data):
    """Compute ECDF for a one-dimensional array of measurements."""
    # Number of data points: n
    n = len(data)

    # x-data for the ECDF: x
    x = np.sort(data)

    # y-data for the ECDF: y
    y = np.arange(1, n+1) / n

    return x, y

# Compute ECDFs
x_set,y_set=ecdf(df_iris['petal length (cm)'][df_iris['species_names']=='setosa'])
x_vers,y_vers=ecdf(df_iris['petal length (cm)'][df_iris['species_names']=='versicolor'])
x_virg,y_virg=ecdf(df_iris['petal length (cm)'][df_iris['species_names']=='virginica'])


# Plot all ECDFs on the same plot
plt.plot(x_set,y_set,marker='.',linestyle='none')
plt.plot(x_vers,y_vers,marker='.',linestyle='none')
plt.plot(x_virg,y_virg,marker='.',linestyle='none')


# Annotate the plot
plt.legend(('setosa', 'versicolor', 'virginica'), loc='lower right')
_ = plt.xlabel('petal length (cm)')
_ = plt.ylabel('ECDF')

# Display the plot
plt.show()

# %%
sns.swarmplot(x='state',y='dem_share',data=df)
plt.show()

# %%
sns.boxplot(x='state',y='dem_share',data=df)
plt.show()

# %%
print('mean:',np.mean(df['dem_share']))
print('median:',np.median(df['dem_share']))
# Out:
# mean: 43.76441441441444
# median: 43.185

# %%
group = df.groupby(by='state')

# %% [raw]
# print(group)

# %%
#making an emperical cumulative distribution function (ECDF)
mean = df.groupby(by='state').mean()
std = df.groupby(by='state').std()
print('mean:',mean)
print('std:',std)
x=np.sort(df['dem_share'])
y=np.arange(1,len(x)+1)/len(x)
plt.plot(x,y,marker='.',linestyle='none')
plt.xlabel('% of Democrat Share of Votes')
plt.ylabel('ECDF of Counties')
plt.margins(0.02)
plt.plot(np.percentile(df['dem_share'],[25,50,75]),[.25,.50,.75],marker='D',color='red',linestyle='none')
plt.show()
# Out:
# mean:          total_votes     dem_votes     rep_votes  dem_share
# state
# FL     125234.985075  63911.552239  60382.447761  41.325075
# OH      64640.465909  33217.431818  30397.829545  44.318182
# PA      89479.656716  48900.940299  39640.074627  45.476418
# std:          total_votes      dem_votes     rep_votes  dem_share
# state
# FL     179237.440664  106412.882043  74383.090611  12.234246
# OH     108092.802038   67641.351714  41110.598068   9.895699
# PA     134704.113297   92572.082439  47860.898226   9.803028

# %%
np.percentile(df['dem_share'],[25,50,75])
# Out:
# array([37.3025, 43.185 , 49.925 ])

# %%
plt.plot(df['dem_share'],df['total_votes']/1000,marker='.',linestyle='none')
plt.xlabel('% of Democrat Share of Votes')
plt.ylabel('Total Votes (Thousands)')
plt.show()

# %%
np.corrcoef(df['dem_share'],df['total_votes'])[0,1]
# Out:
# 0.5361973649586781

# %%
np.random.seed(13)
heads = np.random.random(size=4) < 0.5
print(heads)
np.sum(heads)
# Out:
# [False  True False False]
# 1

# %%
n_fourheads = 0
for i in range(10000):
    heads=np.random.random(size=4) <0.5
    n_heads = np.sum(heads)
    if n_heads==4:
        n_fourheads +=1
print(n_fourheads/10000)
# Out:
# 0.0609
